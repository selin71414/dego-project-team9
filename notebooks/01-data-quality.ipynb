# %% [markdown]
# # Data Quality

# %% [markdown]
# ## Data Retention Strategy
#
# 500/502 rows are retained in the cleaned dataset with quality flags. This approach:
# - Preserves data for transparency and audit trails
# - Allows downstream analysis to handle questionable records
# - Enables sensitivity analysis by including/excluding flagged rows
# - Documents decision points for reproducibility
# - Raw source fields are preserved for traceability.
# - Standardized fields are added as new `_clean` columns.
# - Data quality issues are recorded in `flag_` columns rather than removing records.
# - This supports two valid downstream paths:
#   - use all rows with flags as controls, or
#   - filter to low-risk records (for example, `any_quality_flag == False`) for stricter analyses.
#
# Flagged fields are stored with "_clean" suffix; original values preserved for reference.

# %%
# setup
import json
import re
from pathlib import Path

import numpy as np
import pandas as pd

ROOT = Path.cwd()
if ROOT.name == "notebooks":
    ROOT = ROOT.parent

RAW_PATH = ROOT / "data" / "raw" / "raw_credit_applications.json"
OUT_DIR = ROOT / "data" / "processed"
OUT_DIR.mkdir(parents=True, exist_ok=True)

if not RAW_PATH.exists():
    raise FileNotFoundError(f"Missing raw file: {RAW_PATH}")

print("Raw file exists:", RAW_PATH.exists())
# Out:
# Raw file exists: True

# %% [markdown]
# ## Loading and Flattening Data

# %%
# load raw + flatten main application table
records = json.loads(RAW_PATH.read_text(encoding="utf-8"))

apps_raw = pd.json_normalize(records, sep=".")
apps_raw["source_row"] = np.arange(len(apps_raw))

print("Applications rows:", len(apps_raw))
apps_raw.head(3)
# Out:
# Applications rows: 502
#        _id                                  spending_behavior  \
# 0  app_200  [{'category': 'Shopping', 'amount': 480}, {'ca...
# 1  app_037  [{'category': 'Rent', 'amount': 608}, {'catego...
# 2  app_215              [{'category': 'Rent', 'amount': 109}]
#
#    processing_timestamp applicant_info.full_name       applicant_info.email  \
# 0  2024-01-15T00:00:00Z              Jerry Smith  jerry.smith17@hotmail.com
# 1                   NaN           Brandon Walker  brandon.walker2@yahoo.com
# 2                   NaN              Scott Moore     scott.moore94@mail.com
#
#   applicant_info.ssn applicant_info.ip_address applicant_info.gender  \
# 0        596-64-4340            192.168.48.155                  Male
# 1        425-69-4784              10.1.102.112                     M
# 2        370-78-5178            10.240.193.250                  Male
#
#   applicant_info.date_of_birth applicant_info.zip_code  ...  \
# ...

# %%
# flatten spending behavior to long table
spending_raw = pd.json_normalize(
    records,
    record_path="spending_behavior",
    meta=["_id"],
    errors="ignore",
).rename(columns={"_id": "application_id"})

print("Spending rows:", len(spending_raw))
spending_raw.head(3)
# Out:
# Spending rows: 827
#    category  amount application_id
# 0  Shopping     480        app_200
# 1      Rent     790        app_200
# 2   Alcohol     247        app_200

# %% [markdown]
# ## Quality Profiling

# %%
# quality profiling report
email_re = re.compile(r"^[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\.[A-Za-z]{2,}$")

def is_empty(s: pd.Series) -> pd.Series:
    return s.isna() | s.astype("string").str.strip().eq("")

def add_issue(rows, issue_type, field, count, total):
    rows.append({
        "issue_type": issue_type,
        "field": field,
        "count": int(count),
        "pct_of_rows": round(100 * int(count) / total, 2),
    })

total = len(apps_raw)
rows = []

# Duplicates (uniqueness dimension)
add_issue(rows, "uniqueness", "_id duplicate", apps_raw.duplicated("_id").sum(), total)
ssn_raw = apps_raw["applicant_info.ssn"].astype("string").str.strip()
ssn_non_empty = ssn_raw.notna() & ssn_raw.ne("")
ssn_dup_rows = ssn_non_empty & ssn_raw.duplicated(keep=False)
add_issue(rows, "uniqueness", "applicant_info.ssn duplicate", ssn_dup_rows.sum(), total)

# Missing
for col in [
    "applicant_info.email",
    "applicant_info.ssn",
    "applicant_info.ip_address",
    "applicant_info.gender",
    "applicant_info.date_of_birth",
    "applicant_info.zip_code",
    "financials.annual_income",
    "processing_timestamp",
]:
    add_issue(rows, "completeness", f"{col} missing/blank", is_empty(apps_raw[col]).sum(), total)

# Timeliness: processing timestamps should not be in the future
analysis_date = pd.Timestamp("2026-03-02", tz="UTC")
processing_ts = pd.to_datetime(apps_raw["processing_timestamp"], errors="coerce", utc=True)
processing_ts_future = (~is_empty(apps_raw["processing_timestamp"])) & (processing_ts > analysis_date)
add_issue(rows, "timeliness", "processing_timestamp in future vs analysis date", processing_ts_future.sum(), total)

# Type mismatches
income_is_str = apps_raw["financials.annual_income"].map(lambda x: isinstance(x, str)).fillna(False)
add_issue(rows, "consistency", "financials.annual_income stored as string", income_is_str.sum(), total)

# Inconsistent coding
gender = apps_raw["applicant_info.gender"].astype("string").str.strip()
gender_short_or_blank = gender.isin(["M", "F", ""]) | gender.isna()
add_issue(rows, "consistency", "applicant_info.gender inconsistent coding", gender_short_or_blank.sum(), total)

# DOB format inconsistency
dob = apps_raw["applicant_info.date_of_birth"].astype("string").str.strip()
fmt_iso = dob.str.match(r"^\d{4}-\d{2}-\d{2}$", na=False)
fmt_slash_dmy_mdy = dob.str.match(r"^\d{2}/\d{2}/\d{4}$", na=False)
fmt_slash_ymd = dob.str.match(r"^\d{4}/\d{2}/\d{2}$", na=False)
dob_non_empty = ~is_empty(dob)
dob_inconsistent = dob_non_empty & (fmt_slash_dmy_mdy | fmt_slash_ymd | (~fmt_iso & ~fmt_slash_dmy_mdy & ~fmt_slash_ymd))
add_issue(rows, "consistency", "applicant_info.date_of_birth non-ISO format", dob_inconsistent.sum(), total)

# Credit history start-age consistency
analysis_date_naive = pd.Timestamp("2026-03-02")
dob_parsed_for_age = pd.to_datetime(dob, errors="coerce", dayfirst=True, format="mixed")
age_years_for_age = analysis_date_naive.year - dob_parsed_for_age.dt.year
before_birthday_for_age = (
    (analysis_date_naive.month < dob_parsed_for_age.dt.month)
    | (
        (analysis_date_naive.month == dob_parsed_for_age.dt.month)
        & (analysis_date_naive.day < dob_parsed_for_age.dt.day)
    )
)
age_years_for_age = age_years_for_age - before_birthday_for_age.astype("Int64")
age_months_for_age = age_years_for_age * 12
credit_hist_for_age = pd.to_numeric(apps_raw["financials.credit_history_months"], errors="coerce")
credit_history_started_before_18 = (
    age_years_for_age.notna()
    & credit_hist_for_age.notna()
    & ((age_months_for_age - credit_hist_for_age) < 18 * 12)
)
add_issue(rows, "consistency", "credit history implies start before age 18", credit_history_started_before_18.sum(), total)

# Invalid email
email = apps_raw["applicant_info.email"].astype("string").str.strip()
invalid_email = (~is_empty(email)) & (~email.map(lambda x: bool(email_re.match(str(x)))))
add_issue(rows, "validity", "applicant_info.email invalid format", invalid_email.sum(), total)

# Invalid numeric values
annual_income_num = pd.to_numeric(apps_raw["financials.annual_income"], errors="coerce")
credit_hist = pd.to_numeric(apps_raw["financials.credit_history_months"], errors="coerce")
dti = pd.to_numeric(apps_raw["financials.debt_to_income"], errors="coerce")
savings = pd.to_numeric(apps_raw["financials.savings_balance"], errors="coerce")

add_issue(rows, "validity", "financials.annual_income == 0", (annual_income_num == 0).sum(), total)
add_issue(rows, "validity", "financials.credit_history_months < 0", (credit_hist < 0).sum(), total)
add_issue(rows, "validity", "financials.debt_to_income > 1", (dti > 1).sum(), total)
add_issue(rows, "validity", "financials.savings_balance < 0", (savings < 0).sum(), total)

report_df = (pd.DataFrame(rows).sort_values(["issue_type", "count"], ascending=[True, False])
    .reset_index(drop=True)
)
report_df
# Out:
#       issue_type                                            field  count  \
# 0   completeness               processing_timestamp missing/blank    440
# 1   completeness               applicant_info.email missing/blank      7
# 2   completeness                 applicant_info.ssn missing/blank      5
# 3   completeness          applicant_info.ip_address missing/blank      5
# 4   completeness       applicant_info.date_of_birth missing/blank      5
# 5   completeness           financials.annual_income missing/blank      5
# 6   completeness              applicant_info.gender missing/blank      3
# 7   completeness            applicant_info.zip_code missing/blank      2
# 8    consistency      applicant_info.date_of_birth non-ISO format    157
# 9    consistency        applicant_info.gender inconsistent coding    114
# 10   consistency        financials.annual_income stored as string      8
# 11   consistency       credit history implies start before age 18      1
# ...

# %%
import matplotlib.pyplot as plt
report_df.groupby("issue_type")["count"].sum().sort_values(ascending=False).plot.bar(
    figsize=(7,4), title="Issue Counts by Dimension", xlabel="Dimension", ylabel="Count", rot=20
)
# Out:
# <Axes: title={'center': 'Issue Counts by Dimension'}, xlabel='Dimension', ylabel='Count'>

# %% [markdown]
# ## Field Selection Notes
#
# This quality profiling report uses a **representative subset of fields** per dimension, not every column in the dataset.
#
# - **Completeness:** We prioritize business-critical fields in this part (identity, contact, key financial inputs, and decision metadata). Optional, derived, or low-impact columns are excluded from the summary for readability.
# - **Uniqueness:** Checks are applied to fields expected to be unique (for example, primary IDs and other candidate unique identifiers).
# - **Validity:** We include fields with clear validation rules (format, type, range, or allowed values).
# - **Consistency:** We include fields involved in cross-field logic checks (values that should agree with each other).
# - **Timeliness (if used):** We include timestamp fields where freshness and ordering matter.
#
# ### Why these fields were chosen
# 1. High impact on analysis/model outcomes
# 2. Clear and testable data quality rules
# 3. Broad coverage across records
# 4. Minimal redundancy with other checks

# %% [markdown]
# ### Missing Values Heatmap — All Columns

# %%
# Missing-values heatmap for all columns
# (installs seaborn/matplotlib if missing)

import sys, subprocess, importlib

for pkg in ["matplotlib", "seaborn"]:
    try:
        importlib.import_module(pkg)
    except ModuleNotFoundError:
        subprocess.check_call([sys.executable, "-m", "pip", "install", pkg])

import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(max(10, len(apps_raw.columns) * 0.35), 6))
sns.heatmap(apps_raw.isna(), cbar=True, yticklabels=False, cmap="viridis")
plt.title("Missing Values Heatmap (All Columns)")
plt.xlabel("Columns")
plt.ylabel("Rows")
plt.tight_layout()
plt.show()

# %% [markdown]
# The heatmap above shows null values across all columns in the raw dataset (yellow = missing, purple = present).
#
# **Note on structural nulls:** Several columns appear mostly missing by design and are not data quality issues:
# - `decision.interest_rate` and `decision.approved_amount` are only populated for **approved** applications
# - `decision.rejection_reason` is only populated for **denied** applications
# - `loan_purpose`, `financials.annual_salary`, and `notes` are optional/supplementary fields not present in all records
# - `processing_timestamp` is missing in 87.65% of records , this is a data quality issue and is flagged separately
#
# The completeness analysis in the quality profiling report focuses on business-critical fields only.

# %% [markdown]
# ## Determenistic Cleaning

# %%
# deterministic cleaning
apps_clean = apps_raw.copy()

# Gender normalization
gender_map = {"M": "Male", "Male": "Male", "F": "Female", "Female": "Female"}
apps_clean["applicant_info.gender_clean"] = (
    apps_clean["applicant_info.gender"]
    .astype("string")
    .str.strip()
    .map(gender_map)
    .fillna("Unknown")
)

# DOB normalization to YYYY-MM-DD
# Preserve already-ISO values; parse only non-ISO values.
dob_raw = apps_clean["applicant_info.date_of_birth"].astype("string").str.strip()
iso_mask = dob_raw.str.match(r"^\d{4}-\d{2}-\d{2}$", na=False)

dob_parsed = pd.Series(pd.NaT, index=apps_clean.index, dtype="datetime64[ns]")
dob_parsed.loc[iso_mask] = pd.to_datetime(
    dob_raw[iso_mask], errors="coerce", format="%Y-%m-%d"
)
dob_parsed.loc[~iso_mask] = pd.to_datetime(
    dob_raw[~iso_mask], errors="coerce", dayfirst=True, format="mixed"
)

apps_clean["applicant_info.date_of_birth_clean"] = dob_parsed.dt.strftime("%Y-%m-%d")

# Numeric coercion + outlier replacement with pd.NA
annual_income_num = pd.to_numeric(apps_clean["financials.annual_income"], errors="coerce")
credit_hist_num = pd.to_numeric(apps_clean["financials.credit_history_months"], errors="coerce")
dti_num = pd.to_numeric(apps_clean["financials.debt_to_income"], errors="coerce")
savings_num = pd.to_numeric(apps_clean["financials.savings_balance"], errors="coerce")

flag_zero_annual_income = annual_income_num == 0
flag_negative_credit_history = credit_hist_num < 0
flag_dti_gt_1 = dti_num > 1
flag_negative_savings = savings_num < 0

# Credit history start-age flag
analysis_date_naive = pd.Timestamp("2026-03-02")
age_years_clean = analysis_date_naive.year - dob_parsed.dt.year
before_birthday_clean = (
    (analysis_date_naive.month < dob_parsed.dt.month)
    | (
        (analysis_date_naive.month == dob_parsed.dt.month)
        & (analysis_date_naive.day < dob_parsed.dt.day)
    )
)
age_years_clean = age_years_clean - before_birthday_clean.astype("Int64")
age_months_clean = age_years_clean * 12
flag_credit_history_started_before_18 = (
    age_years_clean.notna()
    & credit_hist_num.notna()
    & ((age_months_clean - credit_hist_num) < 18 * 12)
)

apps_clean["financials.annual_income_clean"] = annual_income_num.astype("Float64").mask(flag_zero_annual_income, pd.NA)
apps_clean["financials.credit_history_months_clean"] = credit_hist_num.astype("Float64").mask(flag_negative_credit_history, pd.NA)
apps_clean["financials.debt_to_income_clean"] = dti_num.astype("Float64").mask(flag_dti_gt_1, pd.NA)
apps_clean["financials.savings_balance_clean"] = savings_num.astype("Float64").mask(flag_negative_savings, pd.NA)

# Flags (transparent governance)
apps_clean["flag_duplicate_id"] = apps_clean.duplicated("_id", keep=False)
ssn_clean = apps_clean["applicant_info.ssn"].astype("string").str.strip()
ssn_clean_non_empty = ssn_clean.notna() & ssn_clean.ne("")
apps_clean["flag_duplicate_ssn"] = ssn_clean_non_empty & ssn_clean.duplicated(keep=False)
apps_clean["flag_invalid_email"] = invalid_email
apps_clean["flag_non_iso_dob_input"] = dob_inconsistent
apps_clean["flag_zero_annual_income"] = flag_zero_annual_income.fillna(False)
apps_clean["flag_negative_credit_history"] = flag_negative_credit_history.fillna(False)
apps_clean["flag_credit_history_started_before_18"] = flag_credit_history_started_before_18.fillna(False)
apps_clean["flag_dti_gt_1"] = flag_dti_gt_1.fillna(False)
apps_clean["flag_negative_savings"] = flag_negative_savings.fillna(False)
processing_ts_clean = pd.to_datetime(apps_clean["processing_timestamp"], errors="coerce", utc=True)
processing_ts_non_empty = apps_clean["processing_timestamp"].astype("string").str.strip().ne("") & apps_clean["processing_timestamp"].notna()
apps_clean["flag_future_processing_timestamp"] = processing_ts_non_empty & (processing_ts_clean > pd.Timestamp("2026-03-02", tz="UTC"))

print("Number of rows:", len(apps_clean))
apps_clean.head(3)
# Out:
# Number of rows: 502
#        _id                                  spending_behavior  \
# 0  app_200  [{'category': 'Shopping', 'amount': 480}, {'ca...
# 1  app_037  [{'category': 'Rent', 'amount': 608}, {'catego...
# 2  app_215              [{'category': 'Rent', 'amount': 109}]
#
#    processing_timestamp applicant_info.full_name       applicant_info.email  \
# 0  2024-01-15T00:00:00Z              Jerry Smith  jerry.smith17@hotmail.com
# 1                   NaN           Brandon Walker  brandon.walker2@yahoo.com
# 2                   NaN              Scott Moore     scott.moore94@mail.com
#
#   applicant_info.ssn applicant_info.ip_address applicant_info.gender  \
# 0        596-64-4340            192.168.48.155                  Male
# 1        425-69-4784              10.1.102.112                     M
# 2        370-78-5178            10.240.193.250                  Male
#
#   applicant_info.date_of_birth applicant_info.zip_code  ... flag_duplicate_id  \
# ...

# %% [markdown]
# ## Deterministic Cleaning Approach
#
# Cleaning is deterministic: the same input always produces the same output because all transformations are explicit, rule-based, and applied in a fixed sequence.
#
# ### Implemented rules
# - Normalize `applicant_info.gender` into `Male`/`Female`/`Unknown`
# - Parse mixed DOB formats and create `applicant_info.date_of_birth_clean` in `YYYY-MM-DD`
# - Coerce numeric fields to numeric types
# - Flag and replace invalid numeric values with `pd.NA` in clean columns:
#   - `annual_income == 0`
#   - `credit_history_months < 0`
#   - `debt_to_income > 1`
#   - `savings_balance < 0`
# - Flag (do not drop) quality issues such as:
#   - duplicate `_id` and duplicate non-empty SSN
#   - invalid email format
#   - non-ISO DOB input
#   - future `processing_timestamp` values
#
# ### Governance note
# Rows are retained, original values are preserved, and quality flags are added for transparent downstream filtering/audit.

# %% [markdown]
# ### Gender Distribution Before-After Cleaning

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 4))

apps_raw["applicant_info.gender"].value_counts(dropna=False).plot(
    kind="bar", ax=axes[0], title="Before Cleaning"
)
axes[0].set_xlabel("Value")
axes[0].set_ylabel("Count")

apps_clean["applicant_info.gender_clean"].value_counts(dropna=False).plot(
    kind="bar", ax=axes[1], title="After Cleaning"
)
axes[1].set_xlabel("Value")

plt.suptitle("Gender Field — Before vs After Normalization")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Duplicate ID Handling

# %%
# Show the 4 rows (full rows), then drop the 2 unwanted ones

# 1) Show all four target rows in full
target_source_rows = [8, 354, 383, 455]
four_rows = apps_clean[apps_clean["source_row"].isin(target_source_rows)].sort_values(["_id", "source_row"])
display(four_rows)

# 2) Drop the two unwanted rows (keep 354 and 383)
drop_source_rows = [8, 455]
apps_clean = apps_clean[~apps_clean["source_row"].isin(drop_source_rows)].reset_index(drop=True)

# Recompute duplicate flags after manual row drop
apps_clean["flag_duplicate_id"] = apps_clean.duplicated("_id", keep=False)
ssn_tmp = apps_clean["applicant_info.ssn"].astype("string").str.strip()
ssn_tmp_non_empty = ssn_tmp.notna() & ssn_tmp.ne("")
apps_clean["flag_duplicate_ssn"] = ssn_tmp_non_empty & ssn_tmp.duplicated(keep=False)

# 3) Quick check of kept rows
display(apps_clean[apps_clean["source_row"].isin([354, 383])].sort_values(["_id", "source_row"]))

print("Number of rows:", len(apps_clean))
# Out:
#          _id                                  spending_behavior  \
# 383  app_001           [{'category': 'Fitness', 'amount': 576}]
# 455  app_001           [{'category': 'Fitness', 'amount': 576}]
# 8    app_042  [{'category': 'Insurance', 'amount': 153}, {'c...
# 354  app_042  [{'category': 'Insurance', 'amount': 153}, {'c...
#
#     processing_timestamp applicant_info.full_name  \
# 383                  NaN         Stephanie Nguyen
# 455                  NaN         Stephanie Nguyen
# 8                    NaN             Joseph Lopez
# 354                  NaN             Joseph Lopez
#
#             applicant_info.email applicant_info.ssn applicant_info.ip_address  \
# 383  stephanie.nguyen47@mail.com        427-90-1892            10.121.120.213
# 455  stephanie.nguyen47@mail.com                NaN                       NaN
# 8        joseph.lopez1@gmail.com        652-70-5530            192.168.91.142
# ...

# %% [markdown]
# For duplicate `_id` records, we kept one canonical row per application and documented the reason.
#
# - **Kept row 383** for `_id = app_001` (dropped row 455) because row 383 is more complete: SSN, IP address, gender, DOB, and ZIP are present, while row 455 has these fields missing and includes `notes = DUPLICATE_ENTRY_ERROR`.
# - **Kept row 354** for `_id = app_042` (dropped row 8) because row 354 includes `notes = RESUBMISSION`, indicating it is the corrected/updated submission.
#
#
# This keeps the most reliable record for each duplicate `_id` while preserving clear audit rationale.

# %% [markdown]
# ## Duplicate SSN Handling

# %%
# Show rows with duplicate SSN (ignoring blank/NaN SSN)
ssn = apps_clean["applicant_info.ssn"].astype("string").str.strip()
valid_ssn = ssn.notna() & ssn.ne("")

dup_ssn_rows = apps_clean[valid_ssn & ssn.duplicated(keep=False)].copy()
dup_ssn_rows["ssn_clean"] = ssn[valid_ssn & ssn.duplicated(keep=False)]

display(dup_ssn_rows.sort_values(["ssn_clean", "_id", "source_row"]))
# Out:
#          _id                                  spending_behavior  \
# 121  app_016         [{'category': 'Groceries', 'amount': 485}]
# 91   app_088    [{'category': 'Transportation', 'amount': 339}]
# 15   app_101  [{'category': 'Groceries', 'amount': 527}, {'c...
# 497  app_234         [{'category': 'Insurance', 'amount': 526}]
#
#     processing_timestamp applicant_info.full_name  \
# 121                  NaN              Gary Wilson
# 91                   NaN           Susan Martinez
# 15                   NaN             Sandra Smith
# 497                  NaN              Samuel Hill
#
#                 applicant_info.email applicant_info.ssn  \
# 121          gary.wilson85@yahoo.com        780-24-9300
# 91   susan.martinez83@protonmail.com        780-24-9300
# 15         sandra.smith99@icloud.com        937-72-8731
# 497     samuel.hill67@protonmail.com        937-72-8731
#
#     applicant_info.ip_address applicant_info.gender  \
# ...

# %% [markdown]
# Rows with duplicate SSN values were reviewed, and they do not appear to be exact duplicates across other key fields.
# Because they may represent distinct applications (rather than accidental row duplication), they were **not removed**.
#
# Instead, these records are **retained and flagged** (`flag_duplicate_ssn = True`) for downstream review and case-by-case investigation.

# %% [markdown]
# ## Spending Table Cleaning

# %%
# Cell 6: clean spending table
spending_clean = spending_raw.copy()
spending_clean["category"] = spending_clean["category"].astype("string").str.strip()
spending_clean["amount"] = pd.to_numeric(spending_clean["amount"], errors="coerce")


print("Number of rows:", len(spending_clean))

spending_clean.head(3)
# Out:
# Number of rows: 827
#    category  amount application_id
# 0  Shopping     480        app_200
# 1      Rent     790        app_200
# 2   Alcohol     247        app_200

# %% [markdown]
# ## Create Cleaning Audit Log
# We create a cleaning_log table that documents each cleaning/flagging rule and how many rows it affected. It then saves the cleaned application data, cleaned spending data, quality report, and cleaning log as CSV files in OUT_DIR, and prints the file paths to confirm the exports succeeded.

# %%
# cleaning log + save outputs
cleaning_log = pd.DataFrame([
    {"field": "applicant_info.gender", "rule": "Normalize M/F/Male/Female to Male/Female; else Unknown",
     "rows_affected": int(gender_short_or_blank.sum())},
    {"field": "applicant_info.date_of_birth", "rule": "Parse mixed formats and standardize to YYYY-MM-DD",
     "rows_affected": int(dob_inconsistent.sum())},
    {"field": "financials.annual_income", "rule": "Coerce to numeric",
     "rows_affected": int(income_is_str.sum())},
    {"field": "flag_duplicate_id", "rule": "Flag duplicate application IDs",
     "rows_affected": int(apps_clean["flag_duplicate_id"].sum())},
    {"field": "flag_duplicate_ssn", "rule": "Flag duplicate SSN values (non-empty only)",
     "rows_affected": int(apps_clean["flag_duplicate_ssn"].sum())},
    {"field": "flag_invalid_email", "rule": "Flag invalid email format records",
     "rows_affected": int(apps_clean["flag_invalid_email"].sum())},
    {"field": "flag_zero_annual_income", "rule": "Flag zero annual income values replaced with pd.NA",
     "rows_affected": int(apps_clean["flag_zero_annual_income"].sum())},
    {"field": "flag_non_iso_dob_input", "rule": "Flag non-ISO date of birth inputs before standardization",
     "rows_affected": int(apps_clean["flag_non_iso_dob_input"].sum())},
    {"field": "flag_negative_credit_history", "rule": "Flag negative credit history months values",
     "rows_affected": int(apps_clean["flag_negative_credit_history"].sum())},
    {"field": "flag_credit_history_started_before_18", "rule": "Flag records where credit history implies start before age 18",
     "rows_affected": int(apps_clean["flag_credit_history_started_before_18"].sum())},
    {"field": "flag_dti_gt_1", "rule": "Flag debt_to_income values greater than 1",
     "rows_affected": int(apps_clean["flag_dti_gt_1"].sum())},
    {"field": "flag_negative_savings", "rule": "Flag negative savings balance values",
     "rows_affected": int(apps_clean["flag_negative_savings"].sum())},
    {"field": "flag_future_processing_timestamp", "rule": "Flag processing timestamps in future vs analysis date",
     "rows_affected": int(apps_clean["flag_future_processing_timestamp"].sum())},
])

apps_out = OUT_DIR / "applications_clean.csv"
spending_out = OUT_DIR / "spending_clean.csv"
report_out = OUT_DIR / "data_quality_report.csv"
log_out = OUT_DIR / "cleaning_log.csv"

apps_clean.to_csv(apps_out, index=False)
spending_clean.to_csv(spending_out, index=False)
report_df.to_csv(report_out, index=False)
cleaning_log.to_csv(log_out, index=False)

print("Saved:", apps_out)
print("Saved:", spending_out)
print("Saved:", report_out)
print("Saved:", log_out)
# Out:
# Saved: c:\Users\gence\dego-project-team9\data\processed\applications_clean.csv
# Saved: c:\Users\gence\dego-project-team9\data\processed\spending_clean.csv
# Saved: c:\Users\gence\dego-project-team9\data\processed\data_quality_report.csv
# Saved: c:\Users\gence\dego-project-team9\data\processed\cleaning_log.csv

# %% [markdown]
# ## Post Cleaning Summary

# %%
# post-cleaning validation summary
# Includes timeliness via flag_future_processing_timestamp.
preferred_flag_order = [
    "flag_duplicate_id",
    "flag_duplicate_ssn",
    "flag_invalid_email",
    "flag_zero_annual_income",
    "flag_non_iso_dob_input",
    "flag_negative_credit_history",
    "flag_credit_history_started_before_18",
    "flag_dti_gt_1",
    "flag_negative_savings",
    "flag_future_processing_timestamp",
]
if "flag_duplicate_ssn" not in apps_clean.columns:
    ssn_tmp = apps_clean["applicant_info.ssn"].astype("string").str.strip()
    ssn_tmp_non_empty = ssn_tmp.notna() & ssn_tmp.ne("")
    apps_clean["flag_duplicate_ssn"] = ssn_tmp_non_empty & ssn_tmp.duplicated(keep=False)
detected_flags = [col for col in apps_clean.columns if col.startswith("flag_")]
flag_cols_all = [col for col in preferred_flag_order if col in detected_flags] + [col for col in detected_flags if col not in preferred_flag_order]
apps_clean["any_quality_flag"] = apps_clean[flag_cols_all].any(axis=1)
flag_cols_display = [col for col in flag_cols_all if col != "flag_future_processing_timestamp"]

total_rows = len(apps_clean)
flagged_rows = apps_clean["any_quality_flag"].sum()
clean_rows = total_rows - flagged_rows

print("\n=== POST-CLEANING DATA VALIDATION ===")
print(f"Total application records: {total_rows:,}")
print(f"Records with ≥1 quality flag: {flagged_rows:,} ({100*flagged_rows/total_rows:.1f}%)")
print(f"Clean rows after cleaning (no quality flags): {clean_rows:,} ({100*clean_rows/total_rows:.1f}%)")
print(f"Records with no flags: {clean_rows:,} ({100*clean_rows/total_rows:.1f}%)")
print(f"\nFlag summary:")
for col in flag_cols_display:
    count = apps_clean[col].sum()
    pct = 100 * count / total_rows
    print(f"  {col}: {count:,} ({pct:.1f}%)")

print(f"\nCleaned field summary:")
print(f"  applicant_info.gender_clean standardized: {int(gender_short_or_blank.sum()):,} ({100*int(gender_short_or_blank.sum())/total_rows:.1f}%)")
print(f"  applicant_info.date_of_birth_clean format-standardized: {int(dob_inconsistent.sum()):,} ({100*int(dob_inconsistent.sum())/total_rows:.1f}%)")
print(f"  financials.annual_income_clean numeric-coerced: {int(income_is_str.sum()):,} ({100*int(income_is_str.sum())/total_rows:.1f}%)")
print(f"  financials.annual_income_clean zero->pd.NA: {int(apps_clean['flag_zero_annual_income'].sum()):,} ({100*int(apps_clean['flag_zero_annual_income'].sum())/total_rows:.1f}%)")
print(f"  financials.credit_history_months_clean negative->pd.NA: {int(apps_clean['flag_negative_credit_history'].sum()):,} ({100*int(apps_clean['flag_negative_credit_history'].sum())/total_rows:.1f}%)")
print(f"  flag_credit_history_started_before_18: {int(apps_clean['flag_credit_history_started_before_18'].sum()):,} ({100*int(apps_clean['flag_credit_history_started_before_18'].sum())/total_rows:.1f}%)")
print(f"  financials.debt_to_income_clean >1->pd.NA: {int(apps_clean['flag_dti_gt_1'].sum()):,} ({100*int(apps_clean['flag_dti_gt_1'].sum())/total_rows:.1f}%)")
print(f"  financials.savings_balance_clean negative->pd.NA: {int(apps_clean['flag_negative_savings'].sum()):,} ({100*int(apps_clean['flag_negative_savings'].sum())/total_rows:.1f}%)")

print(f"\n Data retention strategy: ALL {total_rows:,} rows retained")
print(f" Cleaned fields available with '_clean' or descriptive suffix")
print(f" Original values preserved for audit trail")
print(f" Ready for bias analysis with optional flag-based filtering")
# Out:
# === POST-CLEANING DATA VALIDATION ===
# Total application records: 500
# Records with ≥1 quality flag: 169 (33.8%)
# Clean rows after cleaning (no quality flags): 331 (66.2%)
# Records with no flags: 331 (66.2%)
#
# Flag summary:
#   flag_duplicate_id: 0 (0.0%)
#   flag_duplicate_ssn: 4 (0.8%)
#   flag_invalid_email: 4 (0.8%)
#   flag_zero_annual_income: 1 (0.2%)
#   flag_non_iso_dob_input: 157 (31.4%)
#   flag_negative_credit_history: 2 (0.4%)
#   flag_credit_history_started_before_18: 1 (0.2%)
#   flag_dti_gt_1: 1 (0.2%)
#   flag_negative_savings: 1 (0.2%)
#
# Cleaned field summary:
#   applicant_info.gender_clean standardized: 114 (22.8%)
#   applicant_info.date_of_birth_clean format-standardized: 157 (31.4%)
#   financials.annual_income_clean numeric-coerced: 8 (1.6%)
#   financials.annual_income_clean zero->pd.NA: 1 (0.2%)
#   financials.credit_history_months_clean negative->pd.NA: 2 (0.4%)
#   flag_credit_history_started_before_18: 1 (0.2%)
# ...

# %% [markdown]
# ### Flag Summary

# %%
flag_data = {
    "Duplicate ID": int(apps_clean["flag_duplicate_id"].sum()),
    "Duplicate SSN": int(apps_clean["flag_duplicate_ssn"].sum()),
    "Invalid Email": int(apps_clean["flag_invalid_email"].sum()),
    "Zero Income": int(apps_clean["flag_zero_annual_income"].sum()),
    "Non-ISO DOB": int(apps_clean["flag_non_iso_dob_input"].sum()),
    "Negative Credit History": int(apps_clean["flag_negative_credit_history"].sum()),
    "Credit Start < 18": int(apps_clean["flag_credit_history_started_before_18"].sum()),
    "DTI > 1": int(apps_clean["flag_dti_gt_1"].sum()),
    "Negative Savings": int(apps_clean["flag_negative_savings"].sum()),
}

fig, ax = plt.subplots(figsize=(8, 5))
ax.barh(list(flag_data.keys()), list(flag_data.values()), color="steelblue")
ax.set_xlabel("Records Affected")
ax.set_title("Data Quality Flags - Records Affected per Issue")
for i, v in enumerate(flag_data.values()):
    ax.text(v + 0.5, i, str(v), va="center")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Expanded Cleaning Log

# %%
# expanded cleaning log with all transformations
if "flag_duplicate_ssn" not in apps_clean.columns:
    ssn_tmp = apps_clean["applicant_info.ssn"].astype("string").str.strip()
    ssn_tmp_non_empty = ssn_tmp.notna() & ssn_tmp.ne("")
    apps_clean["flag_duplicate_ssn"] = ssn_tmp_non_empty & ssn_tmp.duplicated(keep=False)

cleaning_log_extended = pd.DataFrame([
    {"field": "applicant_info.gender", "rule": "Normalize M/F/Male/Female to Male/Female/Unknown", 
     "rows_affected": int(gender_short_or_blank.sum()), "handling": "Retain with gender_clean field"},
    {"field": "applicant_info.date_of_birth", "rule": "Parse mixed formats to YYYY-MM-DD", 
     "rows_affected": int(dob_inconsistent.sum()), "handling": "Retain; flag non-ISO inputs"},
    {"field": "financials.annual_income", "rule": "Coerce string values to numeric", 
     "rows_affected": int(income_is_str.sum()), "handling": "Retain with income_clean field"},
    {"field": "flag_duplicate_id", "rule": "Flag duplicate application IDs", 
     "rows_affected": int(apps_clean["flag_duplicate_id"].sum()), "handling": "Retain; flag for review"},
    {"field": "flag_duplicate_ssn", "rule": "Flag duplicate SSN values (non-empty only)", 
     "rows_affected": int(apps_clean["flag_duplicate_ssn"].sum()), "handling": "Retain; flag for review"},
    {"field": "applicant_info.email", "rule": "Validate email format (RFC-like pattern)", 
     "rows_affected": int(invalid_email.sum()), "handling": "Retain; flag invalid emails"},
    {"field": "flag_zero_annual_income", "rule": "Replace annual income == 0 with pd.NA", 
     "rows_affected": int(apps_clean["flag_zero_annual_income"].sum()), "handling": "Retain; flag zero income"},
    {"field": "financials.credit_history_months", "rule": "Replace negative values with pd.NA", 
     "rows_affected": int(apps_clean["flag_negative_credit_history"].sum()), "handling": "Retain; flag original negative values"},
    {"field": "flag_credit_history_started_before_18", "rule": "Flag records where credit history implies start before age 18", 
     "rows_affected": int(apps_clean["flag_credit_history_started_before_18"].sum()), "handling": "Retain; flag for review"},
    {"field": "financials.debt_to_income", "rule": "Replace values > 1 with pd.NA", 
     "rows_affected": int(apps_clean["flag_dti_gt_1"].sum()), "handling": "Retain; flag original invalid DTI"},
    {"field": "financials.savings_balance", "rule": "Replace negative values with pd.NA", 
     "rows_affected": int(apps_clean["flag_negative_savings"].sum()), "handling": "Retain; flag original negative values"},
    {"field": "flag_future_processing_timestamp", "rule": "Flag timestamps later than analysis date", 
     "rows_affected": int(apps_clean["flag_future_processing_timestamp"].sum()), "handling": "Retain; flag future timestamp"},
])

from IPython.display import display

# No optional dependencies (e.g., jinja2) required.
cleaning_log_view = (
    cleaning_log_extended
    .sort_values("rows_affected", ascending=False)
    .reset_index(drop=True)
)
display(cleaning_log_view)
# Out:
#                                     field  \
# 0            applicant_info.date_of_birth
# 1                   applicant_info.gender
# 2                financials.annual_income
# 3                      flag_duplicate_ssn
# 4                    applicant_info.email
# 5        financials.credit_history_months
# 6        flag_future_processing_timestamp
# 7                 flag_zero_annual_income
# 8               financials.debt_to_income
# 9   flag_credit_history_started_before_18
# 10             financials.savings_balance
# 11                      flag_duplicate_id
#
#                                                  rule  rows_affected  \
# 0                   Parse mixed formats to YYYY-MM-DD            157
# 1    Normalize M/F/Male/Female to Male/Female/Unknown            114
# 2                     Coerce string values to numeric              8
# 3          Flag duplicate SSN values (non-empty only)              4
# ...
